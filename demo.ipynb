# %%
import pandas as pd

# %%
df = pd.read_csv('demo_data.csv')
df.head()
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#           short_name                            long_name  age         dob  \
# 0           L. Messi       Lionel Andrés Messi Cuccittini   27  1987-06-24
# 1  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29  1985-02-05
# 2          A. Robben                         Arjen Robben   30  1984-01-23
# 3     Z. Ibrahimović                   Zlatan Ibrahimović   32  1981-10-03
# 4           M. Neuer                         Manuel Neuer   28  1986-03-27
#
#    height_cm  weight_kg  nationality  ... mentality_penalties  \
# 0        169         67    Argentina  ...                  76
# 1        185         80     Portugal  ...                  85
# 2        180         80  Netherlands  ...                  80
# 3        195         95       Sweden  ...                  91
# 4        193         92      Germany  ...                  37
#
#   mentality_composure  defending_marking  defending_standing_tackle  \
# 0                 NaN                 25                         21
# 1                 NaN                 22                         31
# 2                 NaN                 29                         26
# 3                 NaN                 25                         41
# 4                 NaN                 25                         25
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                        20                   6                    11
# 1                        23                   7                    11
# 2                        26                  10                     8
# 3                        27                  13                    15
# 4                        25                  87                    85
#
#   goalkeeping_kicking goalkeeping_positioning  goalkeeping_reflexes
# 0                  15                      14                     8
# 1                  15                      14                    11
# 2                  11                       5                    15
# 3                  10                       9                    12
# 4                  92                      90                    86
#
# [5 rows x 81 columns]

# %%
df.loc[[12],['short_name']]
# Out:
#    short_name
# 12    G. Bale

# %%
import numpy as np

# %%
df.sample(300)
# Out:
#        Unnamed: 0  sofifa_id  \
# 6618         6618     191662
# 4988         4988     198185
# 8526         8526     219751
# 15064       15064     220848
# 5510         5510     214689
# ...           ...        ...
# 13748       13748     224240
# 3762         3762     146634
# 5274         5274     144440
# 2152         2152     190671
# 2766         2766     175787
#
#                                               player_url     short_name  \
# 6618   https://sofifa.com/player/191662/sung-hwan-kim...  Kim Sung Hwan
# 4988   https://sofifa.com/player/198185/lee-w-leandro...            Lee
# 8526   https://sofifa.com/player/219751/alexandre-bar...    Alex Soares
# 15064  https://sofifa.com/player/220848/jakob-andreas...   J. Andreasen
# 5510   https://sofifa.com/player/214689/gonzalo-villa...    G. Villagra
# ...                                                  ...            ...
# 13748  https://sofifa.com/player/224240/niels-de-pauw...     N. De Pauw
# 3762   https://sofifa.com/player/146634/iago-bouzon-a...    Iago Bouzón
# 5274   https://sofifa.com/player/144440/john-alvbage/...     J. Alvbåge
# 2152   https://sofifa.com/player/190671/mike-frantz/1...      M. Frantz
# 2766   https://sofifa.com/player/175787/wason-renteri...    W. Rentería
#
#                                    long_name  age         dob  height_cm  \
# 6618                                 김성환 金城焕   27  1986-12-15        184
# 4988   Lee Winston Leandro da Silva Oliveira   26  1988-03-09        188
# 8526          Alexandre Miguel Barros Soares   23  1991-03-01        178
# 15064                        Jakob Andreasen   20  1994-02-25        180
# 5510            Gonzalo Andrés Villagra Lira   32  1981-09-17        169
# ...                                      ...  ...         ...        ...
# 13748                          Niels De Pauw   18  1996-01-19        190
# 3762                      Iago Bouzón Amoedo   31  1983-03-17        186
# 5274                            John Alvbåge   31  1982-08-10        187
# 2152                             Mike Frantz   27  1986-10-14        182
# 2766           Wason Libardo Rentería Cuesta   28  1985-07-04        186
#
#        weight_kg     nationality  ... mentality_penalties mentality_composure  \
# 6618          78  Korea Republic  ...                  67                 NaN
# 4988          86          Brazil  ...                  21                 NaN
# 8526          65        Portugal  ...                  47                 NaN
# 15064         70         Denmark  ...                  52                 NaN
# 5510          68           Chile  ...                  58                 NaN
# ...          ...             ...  ...                 ...                 ...
# 13748         79         Belgium  ...                  35                 NaN
# 3762          82           Spain  ...                  53                 NaN
# 5274          88          Sweden  ...                  25                 NaN
# 2152          80         Germany  ...                  55                 NaN
# 2766          82        Colombia  ...                  71                 NaN
#
#        defending_marking  defending_standing_tackle  defending_sliding_tackle  \
# 6618                  66                         60                        57
# 4988                  25                         25                        25
# 8526                  53                         54                        58
# 15064                 22                         23                        20
# 5510                  67                         72                        43
# ...                  ...                        ...                       ...
# 13748                 56                         57                        51
# 3762                  75                         66                        70
# 5274                  25                         25                        25
# 2152                  68                         70                        65
# 2766                  31                         46                        23
#
#        goalkeeping_diving  goalkeeping_handling goalkeeping_kicking  \
# 6618                   13                     6                   5
# 4988                   71                    66                  63
# 8526                    8                     6                   6
# 15064                  15                    11                  10
# 5510                   13                    13                  15
# ...                   ...                   ...                 ...
# 13748                  13                    12                  14
# 3762                   10                    10                  13
# 5274                   73                    60                  54
# 2152                   14                    11                   6
# 2766                   12                    12                  15
#
#       goalkeeping_positioning  goalkeeping_reflexes
# 6618                       15                     8
# 4988                       66                    69
# 8526                        9                    13
# 15064                       5                    10
# 5510                        9                    12
# ...                       ...                   ...
# 13748                       6                    10
# 3762                       10                    14
# 5274                       66                    74
# 2152                       14                     7
# 2766                        9                     9
#
# [300 rows x 81 columns]

# %%
random_col = np.random.randint(100,size=len(df))

# %%
df.insert(3,'random_col',random_col)

# %%
df.head()
# Out:
#    Unnamed: 0  sofifa_id                                         player_url  \
# 0           0     158023  https://sofifa.com/player/158023/lionel-messi/...
# 1           1      20801  https://sofifa.com/player/20801/c-ronaldo-dos-...
# 2           2       9014  https://sofifa.com/player/9014/arjen-robben/15...
# 3           3      41236  https://sofifa.com/player/41236/zlatan-ibrahim...
# 4           4     167495  https://sofifa.com/player/167495/manuel-neuer/...
#
#    random_col         short_name                            long_name  age  \
# 0          75           L. Messi       Lionel Andrés Messi Cuccittini   27
# 1          35  Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   29
# 2          58          A. Robben                         Arjen Robben   30
# 3          47     Z. Ibrahimović                   Zlatan Ibrahimović   32
# 4          61           M. Neuer                         Manuel Neuer   28
#
#           dob  height_cm  weight_kg  ... mentality_penalties  \
# 0  1987-06-24        169         67  ...                  76
# 1  1985-02-05        185         80  ...                  85
# 2  1984-01-23        180         80  ...                  80
# 3  1981-10-03        195         95  ...                  91
# 4  1986-03-27        193         92  ...                  37
#
#   mentality_composure defending_marking  defending_standing_tackle  \
# 0                 NaN                25                         21
# 1                 NaN                22                         31
# 2                 NaN                29                         26
# 3                 NaN                25                         41
# 4                 NaN                25                         25
#
#    defending_sliding_tackle  goalkeeping_diving  goalkeeping_handling  \
# 0                        20                   6                    11
# 1                        23                   7                    11
# 2                        26                  10                     8
# 3                        27                  13                    15
# 4                        25                  87                    85
#
#    goalkeeping_kicking goalkeeping_positioning goalkeeping_reflexes
# 0                   15                      14                    8
# 1                   15                      14                   11
# 2                   11                       5                   15
# 3                   10                       9                   12
# 4                   92                      90                   86
#
# [5 rows x 82 columns]

# %%
df['random_col'].where(df['random_col'] >50)
# Out:
# 0        75.0
# 1         NaN
# 2        58.0
# 3         NaN
# 4        61.0
#          ...
# 16150    55.0
# 16151     NaN
# 16152     NaN
# 16153    61.0
# 16154    53.0
# Name: random_col, Length: 16155, dtype: float64
